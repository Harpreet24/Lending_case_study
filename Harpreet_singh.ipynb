# %%
import pandas as pd
import numpy as np
df=pd.read_csv('loan.csv')
df
# Out:
# C:\Users\hs999\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3012: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# 1       60 months   15.27%        59.83     C        C4  ...
# 2       36 months   15.96%        84.33     C        C5  ...
# 3       36 months   13.49%       339.31     C        C1  ...
# 4       60 months   12.69%        67.79     B        B5  ...
# ...           ...      ...          ...   ...       ...  ...
# 39712   36 months    8.07%        78.42     A        A4  ...
# 39713   36 months   10.28%       275.38     C        C1  ...
# 39714   36 months    8.07%       156.84     A        A4  ...
# 39715   36 months    7.43%       155.38     A        A2  ...
# 39716   36 months   13.75%       255.43     E        E2  ...
#
#       num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                    NaN                NaN            NaN               NaN
# 1                    NaN                NaN            NaN               NaN
# 2                    NaN                NaN            NaN               NaN
# 3                    NaN                NaN            NaN               NaN
# 4                    NaN                NaN            NaN               NaN
# ...                  ...                ...            ...               ...
# 39712                NaN                NaN            NaN               NaN
# 39713                NaN                NaN            NaN               NaN
# 39714                NaN                NaN            NaN               NaN
# 39715                NaN                NaN            NaN               NaN
# 39716                NaN                NaN            NaN               NaN
#
#       pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                      0.0       0.0             NaN               NaN
# 1                      0.0       0.0             NaN               NaN
# 2                      0.0       0.0             NaN               NaN
# 3                      0.0       0.0             NaN               NaN
# 4                      0.0       0.0             NaN               NaN
# ...                    ...       ...             ...               ...
# 39712                  NaN       NaN             NaN               NaN
# 39713                  NaN       NaN             NaN               NaN
# 39714                  NaN       NaN             NaN               NaN
# 39715                  NaN       NaN             NaN               NaN
# 39716                  NaN       NaN             NaN               NaN
#
#       total_bc_limit total_il_high_credit_limit
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
# 3                NaN                        NaN
# 4                NaN                        NaN
# ...              ...                        ...
# 39712            NaN                        NaN
# 39713            NaN                        NaN
# 39714            NaN                        NaN
# 39715            NaN                        NaN
# 39716            NaN                        NaN
#
# [39717 rows x 111 columns]

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#         delinq_2yrs  inq_last_6mths  ...  num_tl_90g_dpd_24m  \
# count  39717.000000    39717.000000  ...                 0.0
# mean       0.146512        0.869200  ...                 NaN
# std        0.491812        1.070219  ...                 NaN
# min        0.000000        0.000000  ...                 NaN
# 25%        0.000000        0.000000  ...                 NaN
# 50%        0.000000        1.000000  ...                 NaN
# 75%        0.000000        1.000000  ...                 NaN
# max       11.000000        8.000000  ...                 NaN
#
#        num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count                 0.0             0.0               0.0
# mean                  NaN             NaN               NaN
# std                   NaN             NaN               NaN
# min                   NaN             NaN               NaN
# 25%                   NaN             NaN               NaN
# 50%                   NaN             NaN               NaN
# 75%                   NaN             NaN               NaN
# max                   NaN             NaN               NaN
#
#        pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# count          39020.000000    39678.0              0.0                0.0
# mean               0.043260        0.0              NaN                NaN
# std                0.204324        0.0              NaN                NaN
# min                0.000000        0.0              NaN                NaN
# 25%                0.000000        0.0              NaN                NaN
# 50%                0.000000        0.0              NaN                NaN
# 75%                0.000000        0.0              NaN                NaN
# max                2.000000        0.0              NaN                NaN
#
#        total_bc_limit  total_il_high_credit_limit
# count             0.0                         0.0
# mean              NaN                         NaN
# std               NaN                         NaN
# min               NaN                         NaN
# 25%               NaN                         NaN
# 50%               NaN                         NaN
# 75%               NaN                         NaN
# max               NaN                         NaN
#
# [8 rows x 87 columns]

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
# Lets Drop columns where all values are null. Because all columns have null values
df.drop(df.iloc[:, 53:105], inplace = True, axis = 1)

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# 1       60 months   15.27%        59.83     C        C4  ...
# 2       36 months   15.96%        84.33     C        C5  ...
# 3       36 months   13.49%       339.31     C        C1  ...
# 4       60 months   12.69%        67.79     B        B5  ...
# ...           ...      ...          ...   ...       ...  ...
# 39712   36 months    8.07%        78.42     A        A4  ...
# 39713   36 months   10.28%       275.38     C        C1  ...
# 39714   36 months    8.07%       156.84     A        A4  ...
# 39715   36 months    7.43%       155.38     A        A2  ...
# 39716   36 months   13.75%       255.43     E        E2  ...
#
#       collections_12_mths_ex_med mths_since_last_major_derog policy_code  \
# 0                            0.0                         NaN           1
# 1                            0.0                         NaN           1
# 2                            0.0                         NaN           1
# 3                            0.0                         NaN           1
# 4                            0.0                         NaN           1
# ...                          ...                         ...         ...
# 39712                        NaN                         NaN           1
# 39713                        NaN                         NaN           1
# 39714                        NaN                         NaN           1
# 39715                        NaN                         NaN           1
# 39716                        NaN                         NaN           1
#
#        application_type pub_rec_bankruptcies tax_liens tot_hi_cred_lim  \
# 0            INDIVIDUAL                  0.0       0.0             NaN
# 1            INDIVIDUAL                  0.0       0.0             NaN
# 2            INDIVIDUAL                  0.0       0.0             NaN
# 3            INDIVIDUAL                  0.0       0.0             NaN
# 4            INDIVIDUAL                  0.0       0.0             NaN
# ...                 ...                  ...       ...             ...
# 39712        INDIVIDUAL                  NaN       NaN             NaN
# 39713        INDIVIDUAL                  NaN       NaN             NaN
# 39714        INDIVIDUAL                  NaN       NaN             NaN
# 39715        INDIVIDUAL                  NaN       NaN             NaN
# 39716        INDIVIDUAL                  NaN       NaN             NaN
#
#       total_bal_ex_mort total_bc_limit total_il_high_credit_limit
# 0                   NaN            NaN                        NaN
# 1                   NaN            NaN                        NaN
# 2                   NaN            NaN                        NaN
# 3                   NaN            NaN                        NaN
# 4                   NaN            NaN                        NaN
# ...                 ...            ...                        ...
# 39712               NaN            NaN                        NaN
# 39713               NaN            NaN                        NaN
# 39714               NaN            NaN                        NaN
# 39715               NaN            NaN                        NaN
# 39716               NaN            NaN                        NaN
#
# [39717 rows x 59 columns]

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim',
#        'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit'],
#       dtype='object')

# %%
# Drop additional columns we don't need these as these are mostly nulls.

columns_drop_list1 = ["desc","mths_since_last_delinq","mths_since_last_record","next_pymnt_d","tot_hi_cred_lim"]
df.drop(labels = columns_drop_list1, axis =1, inplace=True)
columns_drop_list2 = ["mths_since_last_major_derog","total_bal_ex_mort","total_bc_limit","total_il_high_credit_limit"]
df.drop(labels = columns_drop_list2, axis =1, inplace=True)
columns_drop_list3 = ["member_id","url","emp_title","zip_code","tax_liens"]
df.drop(labels = columns_drop_list3, axis =1, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                               0
# loan_amnt                        0
# funded_amnt                      0
# funded_amnt_inv                  0
# term                             0
# int_rate                         0
# installment                      0
# grade                            0
# sub_grade                        0
# emp_length                    1075
# home_ownership                   0
# annual_inc                       0
# verification_status              0
# issue_d                          0
# loan_status                      0
# pymnt_plan                       0
# purpose                          0
# title                           11
# addr_state                       0
# dti                              0
# delinq_2yrs                      0
# earliest_cr_line                 0
# inq_last_6mths                   0
# open_acc                         0
# pub_rec                          0
# revol_bal                        0
# revol_util                      50
# total_acc                        0
# initial_list_status              0
# out_prncp                        0
# out_prncp_inv                    0
# total_pymnt                      0
# total_pymnt_inv                  0
# total_rec_prncp                  0
# total_rec_int                    0
# total_rec_late_fee               0
# recoveries                       0
# collection_recovery_fee          0
# last_pymnt_d                    71
# last_pymnt_amnt                  0
# last_credit_pull_d               2
# collections_12_mths_ex_med      56
# policy_code                      0
# application_type                 0
# pub_rec_bankruptcies           697
# dtype: int64

# %%
df
# Out:
#             id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0      1077501       5000         5000           4975.0   36 months   10.65%
# 1      1077430       2500         2500           2500.0   60 months   15.27%
# 2      1077175       2400         2400           2400.0   36 months   15.96%
# 3      1076863      10000        10000          10000.0   36 months   13.49%
# 4      1075358       3000         3000           3000.0   60 months   12.69%
# ...        ...        ...          ...              ...         ...      ...
# 39712    92187       2500         2500           1075.0   36 months    8.07%
# 39713    90665       8500         8500            875.0   36 months   10.28%
# 39714    90395       5000         5000           1325.0   36 months    8.07%
# 39715    90376       5000         5000            650.0   36 months    7.43%
# 39716    87023       7500         7500            800.0   36 months   13.75%
#
#        installment grade sub_grade emp_length  ... total_rec_late_fee  \
# 0           162.87     B        B2  10+ years  ...               0.00
# 1            59.83     C        C4   < 1 year  ...               0.00
# 2            84.33     C        C5  10+ years  ...               0.00
# 3           339.31     C        C1  10+ years  ...              16.97
# 4            67.79     B        B5     1 year  ...               0.00
# ...            ...   ...       ...        ...  ...                ...
# 39712        78.42     A        A4    4 years  ...               0.00
# 39713       275.38     C        C1    3 years  ...               0.00
# 39714       156.84     A        A4   < 1 year  ...               0.00
# 39715       155.38     A        A2   < 1 year  ...               0.00
# 39716       255.43     E        E2   < 1 year  ...               0.00
#
#        recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt  \
# 0            0.00                    0.00       Jan-15          171.62
# 1          117.08                    1.11       Apr-13          119.66
# 2            0.00                    0.00       Jun-14          649.91
# 3            0.00                    0.00       Jan-15          357.48
# 4            0.00                    0.00       May-16           67.79
# ...           ...                     ...          ...             ...
# 39712        0.00                    0.00       Jul-10           80.90
# 39713        0.00                    0.00       Jul-10          281.94
# 39714        0.00                    0.00       Apr-08            0.00
# 39715        0.00                    0.00       Jan-08            0.00
# 39716        0.00                    0.00       Jun-10          256.59
#
#       last_credit_pull_d collections_12_mths_ex_med policy_code  \
# 0                 May-16                        0.0           1
# 1                 Sep-13                        0.0           1
# 2                 May-16                        0.0           1
# 3                 Apr-16                        0.0           1
# 4                 May-16                        0.0           1
# ...                  ...                        ...         ...
# 39712             Jun-10                        NaN           1
# 39713             Jul-10                        NaN           1
# 39714             Jun-07                        NaN           1
# 39715             Jun-07                        NaN           1
# 39716             Jun-10                        NaN           1
#
#       application_type  pub_rec_bankruptcies
# 0           INDIVIDUAL                   0.0
# 1           INDIVIDUAL                   0.0
# 2           INDIVIDUAL                   0.0
# 3           INDIVIDUAL                   0.0
# 4           INDIVIDUAL                   0.0
# ...                ...                   ...
# 39712       INDIVIDUAL                   NaN
# 39713       INDIVIDUAL                   NaN
# 39714       INDIVIDUAL                   NaN
# 39715       INDIVIDUAL                   NaN
# 39716       INDIVIDUAL                   NaN
#
# [39717 rows x 45 columns]

# %%
# Data cleaning
# Lets format employment length column to have only numbers. It may play important role in analysis further.

df['emp_length'].fillna('0',inplace=True)
df['emp_length']=df['emp_length'].str.extract('(\d+)')
df
# Out:
#             id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0      1077501       5000         5000           4975.0   36 months   10.65%
# 1      1077430       2500         2500           2500.0   60 months   15.27%
# 2      1077175       2400         2400           2400.0   36 months   15.96%
# 3      1076863      10000        10000          10000.0   36 months   13.49%
# 4      1075358       3000         3000           3000.0   60 months   12.69%
# ...        ...        ...          ...              ...         ...      ...
# 39712    92187       2500         2500           1075.0   36 months    8.07%
# 39713    90665       8500         8500            875.0   36 months   10.28%
# 39714    90395       5000         5000           1325.0   36 months    8.07%
# 39715    90376       5000         5000            650.0   36 months    7.43%
# 39716    87023       7500         7500            800.0   36 months   13.75%
#
#        installment grade sub_grade emp_length  ... total_rec_late_fee  \
# 0           162.87     B        B2         10  ...               0.00
# 1            59.83     C        C4          1  ...               0.00
# 2            84.33     C        C5         10  ...               0.00
# 3           339.31     C        C1         10  ...              16.97
# 4            67.79     B        B5          1  ...               0.00
# ...            ...   ...       ...        ...  ...                ...
# 39712        78.42     A        A4          4  ...               0.00
# 39713       275.38     C        C1          3  ...               0.00
# 39714       156.84     A        A4          1  ...               0.00
# 39715       155.38     A        A2          1  ...               0.00
# 39716       255.43     E        E2          1  ...               0.00
#
#        recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt  \
# 0            0.00                    0.00       Jan-15          171.62
# 1          117.08                    1.11       Apr-13          119.66
# 2            0.00                    0.00       Jun-14          649.91
# 3            0.00                    0.00       Jan-15          357.48
# 4            0.00                    0.00       May-16           67.79
# ...           ...                     ...          ...             ...
# 39712        0.00                    0.00       Jul-10           80.90
# 39713        0.00                    0.00       Jul-10          281.94
# 39714        0.00                    0.00       Apr-08            0.00
# 39715        0.00                    0.00       Jan-08            0.00
# 39716        0.00                    0.00       Jun-10          256.59
#
#       last_credit_pull_d collections_12_mths_ex_med policy_code  \
# 0                 May-16                        0.0           1
# 1                 Sep-13                        0.0           1
# 2                 May-16                        0.0           1
# 3                 Apr-16                        0.0           1
# 4                 May-16                        0.0           1
# ...                  ...                        ...         ...
# 39712             Jun-10                        NaN           1
# 39713             Jul-10                        NaN           1
# 39714             Jun-07                        NaN           1
# 39715             Jun-07                        NaN           1
# 39716             Jun-10                        NaN           1
#
#       application_type  pub_rec_bankruptcies
# 0           INDIVIDUAL                   0.0
# 1           INDIVIDUAL                   0.0
# 2           INDIVIDUAL                   0.0
# 3           INDIVIDUAL                   0.0
# 4           INDIVIDUAL                   0.0
# ...                ...                   ...
# 39712       INDIVIDUAL                   NaN
# 39713       INDIVIDUAL                   NaN
# 39714       INDIVIDUAL                   NaN
# 39715       INDIVIDUAL                   NaN
# 39716       INDIVIDUAL                   NaN
#
# [39717 rows x 45 columns]

# %%
# pub_rec_bankruptcies can be cleaned for further analysis.
print("Before cleaning:")
print(df['pub_rec_bankruptcies'].isnull().sum())
print("After cleaning:")
df['pub_rec_bankruptcies'].fillna('Not Known',inplace=True)
print(df['pub_rec_bankruptcies'].isnull().sum())
# Out:
# Before cleaning:
# 697
# After cleaning:
# 0

# %%
# Lets remove % symbol from intrest rate column so that it can be used in calculations
df['int_rate'] = df['int_rate'].str.rstrip('%')

# Lets remove % symbol from revol_util column so that it can be used in calculations
df['revol_util'] = df['revol_util'].str.rstrip('%')

# %%
# convert amount columns into numeric data to find some correlation among important ones.

cols1 = ['loan_amnt','funded_amnt','int_rate','funded_amnt_inv','installment','annual_inc','dti','total_pymnt']
df[cols1] = df[cols1].apply(pd.to_numeric)

# %%
# Lets take a look on important variable loan status in total loans issued
df['loan_status'].value_counts()
#Maximum loans were fully paid
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
# Lets take a look on important variable purpose of loan in total loans issued
df['purpose'].value_counts()
# Out:
# debt_consolidation    18641
# credit_card            5130
# other                  3993
# home_improvement       2976
# major_purchase         2187
# small_business         1828
# car                    1549
# wedding                 947
# medical                 693
# moving                  583
# vacation                381
# house                   381
# educational             325
# renewable_energy        103
# Name: purpose, dtype: int64

# %%
df.issue_d
# Out:
# 0        Dec-11
# 1        Dec-11
# 2        Dec-11
# 3        Dec-11
# 4        Dec-11
#           ...
# 39712    Jul-07
# 39713    Jul-07
# 39714    Jul-07
# 39715    Jul-07
# 39716    Jun-07
# Name: issue_d, Length: 39717, dtype: object

# %% [markdown]
# # Derived Columns

# %%
#Lets derive some new columns using existing data as it may further used in analysis.
# create month and year columns separately
df['issue_d'] = pd.to_datetime(df['issue_d'], format='%b-%y')
df['year']=df['issue_d'].dt.year
df['month']=df['issue_d'].dt.month
df
# Out:
#             id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0      1077501       5000         5000           4975.0   36 months     10.65
# 1      1077430       2500         2500           2500.0   60 months     15.27
# 2      1077175       2400         2400           2400.0   36 months     15.96
# 3      1076863      10000        10000          10000.0   36 months     13.49
# 4      1075358       3000         3000           3000.0   60 months     12.69
# ...        ...        ...          ...              ...         ...       ...
# 39712    92187       2500         2500           1075.0   36 months      8.07
# 39713    90665       8500         8500            875.0   36 months     10.28
# 39714    90395       5000         5000           1325.0   36 months      8.07
# 39715    90376       5000         5000            650.0   36 months      7.43
# 39716    87023       7500         7500            800.0   36 months     13.75
#
#        installment grade sub_grade emp_length  ... collection_recovery_fee  \
# 0           162.87     B        B2         10  ...                    0.00
# 1            59.83     C        C4          1  ...                    1.11
# 2            84.33     C        C5         10  ...                    0.00
# 3           339.31     C        C1         10  ...                    0.00
# 4            67.79     B        B5          1  ...                    0.00
# ...            ...   ...       ...        ...  ...                     ...
# 39712        78.42     A        A4          4  ...                    0.00
# 39713       275.38     C        C1          3  ...                    0.00
# 39714       156.84     A        A4          1  ...                    0.00
# 39715       155.38     A        A2          1  ...                    0.00
# 39716       255.43     E        E2          1  ...                    0.00
#
#        last_pymnt_d last_pymnt_amnt last_credit_pull_d  \
# 0            Jan-15          171.62             May-16
# 1            Apr-13          119.66             Sep-13
# 2            Jun-14          649.91             May-16
# 3            Jan-15          357.48             Apr-16
# 4            May-16           67.79             May-16
# ...             ...             ...                ...
# 39712        Jul-10           80.90             Jun-10
# 39713        Jul-10          281.94             Jul-10
# 39714        Apr-08            0.00             Jun-07
# 39715        Jan-08            0.00             Jun-07
# 39716        Jun-10          256.59             Jun-10
#
#       collections_12_mths_ex_med policy_code application_type  \
# 0                            0.0           1       INDIVIDUAL
# 1                            0.0           1       INDIVIDUAL
# 2                            0.0           1       INDIVIDUAL
# 3                            0.0           1       INDIVIDUAL
# 4                            0.0           1       INDIVIDUAL
# ...                          ...         ...              ...
# 39712                        NaN           1       INDIVIDUAL
# 39713                        NaN           1       INDIVIDUAL
# 39714                        NaN           1       INDIVIDUAL
# 39715                        NaN           1       INDIVIDUAL
# 39716                        NaN           1       INDIVIDUAL
#
#       pub_rec_bankruptcies  year  month
# 0                      0.0  2011     12
# 1                      0.0  2011     12
# 2                      0.0  2011     12
# 3                      0.0  2011     12
# 4                      0.0  2011     12
# ...                    ...   ...    ...
# 39712            Not Known  2007      7
# 39713            Not Known  2007      7
# 39714            Not Known  2007      7
# 39715            Not Known  2007      7
# 39716            Not Known  2007      6
#
# [39717 rows x 47 columns]

# %% [markdown]
# # Univariate Analysis

# %%
df['loan_amnt'].describe()
# Out:
# count    39717.000000
# mean     11219.443815
# std       7456.670694
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
import seaborn as sns
sns.boxplot(df['loan_amnt'])
# Out:
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='loan_amnt'>

# %%
# Basic statistics with .describe() -Quantitative Variables
df['annual_inc'].describe()
# Out:
# count    3.971700e+04
# mean     6.896893e+04
# std      6.379377e+04
# min      4.000000e+03
# 25%      4.040400e+04
# 50%      5.900000e+04
# 75%      8.230000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
#Remove Outlier
df=df[df["annual_inc"] < df["annual_inc"].quantile(0.99)]
df['annual_inc'].describe()
# Out:
# count     39319.000000
# mean      65524.215803
# std       35215.885297
# min        4000.000000
# 25%       40000.000000
# 50%       58000.000000
# 75%       81000.000000
# max      234996.000000
# Name: annual_inc, dtype: float64

# %%
sns.boxplot(df['annual_inc'])
# Out:
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='annual_inc'>

# %%
# Lets see distribution of three loan amount fields using distribution plot.
# Quantitative Variables
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
sns.set_style("whitegrid")
# subplot 1
plt.subplot(2, 3, 1)
ax = sns.distplot(df['loan_amnt'],rug = True)
plt.title('Loan Amount Field',size=14)
plt.xlabel('Loan Amount',size=14)
# subplot 2
plt.subplot(2, 3, 2)
ax = sns.distplot(df['funded_amnt'],rug = True)
plt.title('Funded Amount Field',size=14)
plt.xlabel('Funded Amount',size=14)
# subplot 2
plt.subplot(2, 3, 3)
ax = sns.distplot(df['funded_amnt_inv'],rug = True)
plt.title('Funded Amount Inv. Field',size=14)
plt.xlabel('Funded Amount Inv.',size=14)
#plt.show()
plt.savefig('test1.jpg')
# Out:
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
# Univariate Analysis - Unordered Categorical Variables - Loan Status

plt.figure(figsize=(10,8))
sns.set_style("dark")
ax = sns.countplot(x="loan_status",data=df,palette='mako')
plt.title('Loan Status',size=20)
plt.xlabel('Loan Status',size=10)
plt.ylabel('Loan Application Count',size=10)            
# To show count of values above bars
s=df['loan_status'].value_counts()
for i, v in s.reset_index().iterrows():
    ax.text(i, v.loan_status + 0.3 , v.loan_status, color='k')
plt.savefig('bargraph.png')

# %%
plt.figure(figsize=(15,8))
sns.set_style("dark")
# subplot 1
plt.subplot(2, 2, 1)
ax = sns.distplot(df['annual_inc'],rug = True)
plt.title('Annual Income - Distribution Plot',size=16)
plt.xlabel('Annual Income',size=14)
# subplot 2
plt.subplot(2, 2, 2)
plt.title('Annual Income - Box Plot')
ax = sns.boxplot(y=df['annual_inc'])
plt.title('Annual Income - Box Plot',size=16)
plt.ylabel('Annual Income',size=16)
plt.show()
# Below plots show that most of the borrower's Annual incomes are in range of 40000- 80000
# Out:
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hs999\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(14,8),facecolor='b')
sns.set_style("dark")
ax = sns.countplot(y="purpose",data=df,hue='loan_status',palette='GnBu_d')
ax.set_title('Purpose Of Loan',fontsize=14,color='w')
ax.set_ylabel('Purpose Of Loan',fontsize=14,color = 'w')
ax.set_xlabel('Loan Application Count',fontsize=14,color = 'w')
plt.savefig('bargraph.jpg')
#plt.show()

# %%
# Univariate Analysis - Unordered Categorical Variables - Home Ownership

plt.figure(figsize=(10,6))
ax = sns.countplot(x="home_ownership",data=df,hue='loan_status',palette='GnBu_d')
ax.legend(bbox_to_anchor=(1, 1))
plt.title('Home Ownership',size=14)
plt.xlabel('Home Ownership',size=14)
plt.ylabel('Loan Application Count',size=14)      
plt.show()

# Below plot shows that most of them living in rented home or mortgazed their home.

# %%
# Univariate Analysis - Ordered Categorical Variables- Loan Paying Term
plt.figure(figsize=(10,6))
ax = sns.countplot(x="term",data=df,hue='loan_status')
plt.title('Loan Paying Term',size=14)
plt.xlabel('Loan Repayment Term',size=14)
plt.ylabel('Loan Application Count',size=14)      
ax.legend(bbox_to_anchor=(1, 1))
plt.savefig('abc.jpg')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # ##Bivariate Analysis : # In this part of analysis, lets try to analyze the loan status against some important columns which might have played # important role in charged off of loans. Lets try to find proportion of charged offs in some categories. # To calculate the proportion of charged off loans, will do these below steps: # Group loans by different variables and loan status, get the count,use .unstack() to return a DataFrame. # Since we’re going to use this for further analysis, it will be helpful to use .reset_index() to clean up the index. # Assign the new DataFrame to a variable. # Create a simple derived column that sums charged off,current and fully paid loans for each category. # Divide the number of charged off loans by the total number of loans to get the proportion of charged off loans. # Store this as another derived column. # Finally, output the whole table, sorted by proportion of charged off in each category issued loans.

# %%
# Bivariate Analysis - Puprose of loan vs Loan amount
# Box Plot

plt.figure(figsize=(12,8))
ax = sns.boxplot(y='purpose', x='loan_amnt', data =df)
plt.title('Purpose of Loan vs Loan Amount',size=15)
plt.ylabel('Purpose of Loan',size=14)
plt.xlabel('Loan Amount',size=14)
plt.savefig('loanamt.jpg')
plt.show()

# Median,95th percentile,75th percentile of loan amount is highest for loan taken for small business purpose among all purposes.
# Debt consolidation is second and Credit card comes 3rd.

# %%
plt.figure(figsize=(10,6))
ax = sns.boxplot(y='int_rate', x='term', data =df,palette='rainbow')
plt.title('Term of loan vs Interest Rate',size=14)
plt.ylabel('Interest Rate',size=12)
plt.xlabel('Term of loan',size=12)
plt.show()
# It is clear that avearge intrest rate is higher for 60 months loan term.
# Most of the loans issued for longer term had higher intrest rates for repayement.

# %%
# Bivariate Analysis - Grade vs Interest Rate
# Box Plot

plt.figure(figsize=(14,8))
ax = sns.boxplot(y='int_rate', x='grade', data =df)
plt.title('Grade vs Interest Rate',size=15)
plt.ylabel('Interest Rate',size=14)
plt.xlabel('Grade',size=14)
plt.show()

# A-grade is a top letter grade for a lender to assign to a borrower.
# The higher the borrower's credit grade,the lower the interest rate offered to that borrower on a loan.
# It is clear that intrest rate is increasing with grades moving from A to F.

# %%
# BarPlot to show variation of annual income across grade for every loan status.
plt.figure(figsize=(10,6), dpi=80)
ax=sns.barplot(x='grade', y='annual_inc', hue="loan_status", data=df, estimator=np.mean)
plt.title('Grade vs Annual income',size=15)
plt.ylabel('Annual income',size=14)
plt.xlabel('Grades',size=14)
plt.show()

# %%
# Bivariate Analysis - year vs Interest Rate
# Box Plot

plt.figure(figsize=(14,8))
ax = sns.boxplot(y='int_rate', x='year', data =df,palette='rainbow')
plt.title('Year vs Interest Rate',size=15)
plt.ylabel('Interest Rate',size=14)
plt.xlabel('Year',size=14)
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
# Bivariate Analysis - Correlation Matrix-Quantitative Variables
# Heatmap to show closeness among numerical variables.
import matplotlib.pyplot as plt
df1 = df.corr()
plt.figure(figsize=(20,18))
sns.set(font_scale=1.1)
sns.heatmap(df1,annot=True,cmap="BrBG",linewidths=.5)
plt.savefig('heatmap.png')

# %%
# Drop additional columns which are not needed further in analysis.

columns_drop_list4 = ["application_type","policy_code","initial_list_status","installment","pymnt_plan"]
df.drop(labels = columns_drop_list4, axis =1, inplace=True)
print(df.shape)
# Out:
# (39319, 42)
# C:\Users\hs999\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Conclusion:-
# After analysing the datasets, there are few attributes of a client with which the bank would be able to identify if they will repay the loan or not.
